# %%
import numpy as np
import pandas as pd
import os
print(os.getcwd())
# Out:
# /home/jovyan/work

# %%
X_train = np.load('/home/jovyan/work/data/processed/X_train.npy')
X_val   = np.load('/home/jovyan/work/data/processed/X_val.npy'  )
X_test  = np.load('/home/jovyan/work/data/processed/X_test.npy' )
y_train = np.load('/home/jovyan/work/data/processed/y_train.npy')
y_val   = np.load('/home/jovyan/work/data/processed/y_val.npy'  )
y_test  = np.load('/home/jovyan/work/data/processed/y_test.npy' )

# %%
X_train.shape
# Out:
# (25372, 59)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(2)

# %%
X_train = poly.fit_transform(X_train)

# %%
# Solution:
X_val = poly.transform(X_val)
X_test = poly.transform(X_test)

# %%
# Solution:
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from joblib import dump  

dump(reg,  '../models/linear_poly_2.joblib')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-2e6254115030> in <module>
#       1 from joblib import dump
#       2
# ----> 3 dump(reg,  '../models/linear_poly_2.joblib')
#
# /opt/conda/lib/python3.7/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     502             NumpyPickler(f, protocol=protocol).dump(value)
#     503     elif is_filename:
# --> 504         with open(filename, 'wb') as f:
#     505             NumpyPickler(f, protocol=protocol).dump(value)
#     506     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/linear_poly_2.joblib'
